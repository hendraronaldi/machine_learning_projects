# %% [markdown]
# #About the Data
# The data contains industry trends, investment insights and individual company information. There are 48 columns/features. Some of the features are:
# ###Feature
# * age_first_funding_year – quantitative
# * age_last_funding_year – quantitative
# * relationships – quantitative
# * funding_rounds – quantitative
# * funding_total_usd – quantitative
# * milestones – quantitative
# * age_first_milestone_year – quantitative
# * age_last_milestone_year – quantitative
# * state – categorical
# * industry_type – categorical
# * has_VC – categorical
# * has_angel – categorical
# * has_roundA – categorical
# * has_roundB – categorical
# * has_roundC – categorical
# * has_roundD – categorical
# * avg_participants – quantitative
# * is_top500 – categorical
# ###Target
# * status(acquired/closed) – categorical (the target variable, if a startup is ‘acquired’ by some other organization, means the startup succeed)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/startupdata/training_set_label.csv" )
test_df = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/startupdata/testing_set_label.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 state_code   latitude  ...  avg_participants is_top500    status
# 0        1005         CA  42.358880  ...            1.0000         0  acquired
# 1         204         CA  37.238916  ...            4.7500         1  acquired
# 2        1001         CA  32.901049  ...            4.0000         1  acquired
# 3         738         CA  37.320309  ...            3.3333         1  acquired
# 4        1002         CA  37.779281  ...            1.0000         1    closed
#
# [5 rows x 48 columns]

# %%
df.tail()
# Out:
#      Unnamed: 0 state_code   latitude  ...  avg_participants is_top500    status
# 918         352         CA  37.740594  ...            6.0000         1  acquired
# 919         721         MA  42.504817  ...            2.6667         1    closed
# 920         557         CA  37.408261  ...            8.0000         1    closed
# 921         589         CA  37.556732  ...            1.0000         1  acquired
# 922         462         CA  37.386778  ...            3.0000         1  acquired
#
# [5 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                923 non-null    int64
#  1   state_code                923 non-null    object
#  2   latitude                  923 non-null    float64
#  3   longitude                 923 non-null    float64
#  4   zip_code                  923 non-null    object
#  5   id                        923 non-null    object
#  6   city                      923 non-null    object
#  7   Unnamed: 6                430 non-null    object
#  8   name                      923 non-null    object
#  9   founded_at                923 non-null    object
#  10  closed_at                 335 non-null    object
#  11  first_funding_at          923 non-null    object
#  12  last_funding_at           923 non-null    object
# ...

# %% [markdown]
# Missing Values Exist

# %%
df.describe()
# Out:
#         Unnamed: 0    latitude  ...  avg_participants   is_top500
# count   923.000000  923.000000  ...        923.000000  923.000000
# mean    572.297941   38.517442  ...          2.838586    0.809317
# std     333.585431    3.741497  ...          1.874601    0.393052
# min       1.000000   25.752358  ...          1.000000    0.000000
# 25%     283.500000   37.388869  ...          1.500000    1.000000
# 50%     577.000000   37.779281  ...          2.500000    1.000000
# 75%     866.500000   40.730646  ...          3.800000    1.000000
# max    1153.000000   59.335232  ...         16.000000    1.000000
#
# [8 rows x 34 columns]

# %% [markdown]
# Analyse Data

# %%
# remove unused column
col_to_drop = [
    'Unnamed: 0', 'latitude', 'longitude', 'zip_code', 'id', 'city', 'Unnamed: 6', 'name', 'state_code.1', 'object_id', 'category_code',
    'founded_at',
    'state_code',
    'first_funding_at',
    'last_funding_at',
    'age_first_milestone_year',
    'age_last_milestone_year'
]
df = df.drop(col_to_drop, axis=1)
df.head()
# Out:
#   closed_at  age_first_funding_year  ...  is_top500    status
# 0       NaN                  2.2493  ...          0  acquired
# 1       NaN                  5.1260  ...          1  acquired
# 2       NaN                  1.0329  ...          1  acquired
# 3       NaN                  3.1315  ...          1  acquired
# 4  10-01-12                  0.0000  ...          1    closed
#
# [5 rows x 31 columns]

# %%
# closed at seems to be suspicious
print('Closed at nan')
df[df.closed_at.isnull()].status.value_counts()
# Out:
# Closed at nan
# acquired    588
# Name: status, dtype: int64

# %%
print('Closed at non nan')
df[~df.closed_at.isnull()].status.value_counts()
# Out:
# Closed at non nan
# closed      326
# acquired      9
# Name: status, dtype: int64

# %%
df = df.drop(['closed_at'], axis=1)

# %%
df.head()

# %% [markdown]
# ### Data Preparation

# %%
X = df.drop(['status'], axis=1).values
y = df['status'].values

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=1)

# %% [markdown]
# ### Model Train and Evaluation

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

# %%
clf = RandomForestClassifier()
model = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, verbose=2)

# %%
model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 1009 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 1440 out of 1440 | elapsed: 12.7min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
# ...

# %%
best_model = model.best_estimator_
y_val_pred = best_model.predict(X_val)

# %% [markdown]
# Confusion Matrix and Classification Report

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(confusion_matrix(y_val, y_val_pred), annot=True, linewidths=0.5)
plt.show()

# %%
print(classification_report(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#     acquired       0.74      0.91      0.82       145
#       closed       0.75      0.47      0.58        86
#
#     accuracy                           0.74       231
#    macro avg       0.75      0.69      0.70       231
# weighted avg       0.75      0.74      0.73       231

# %% [markdown]
# Dummy predictions

# %%
test_df.closed_at.isnull().sum()
pred = ['acquired' if i else 'closed' for i in test_df.closed_at.isnull()]
r_df = pd.DataFrame({
    'prediction': pred
})
r_df.to_csv('ssp_dummy_pred.csv', index=False)

# %%
# dummy predictions give 99% accuracy :(
