# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
from tensorflow.keras.datasets import cifar10

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## load dataset

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_test.shape
# Out:
# (10000, 1)

# %% [markdown]
# ## Visualize data

# %% [markdown]
# grid view plot

# %%
x_grid = 15
y_grid = 15
n_training = X_train.shape[0]

fig, axes = plt.subplots(x_grid, y_grid, figsize=(25, 25))
axes = axes.ravel()

for i in range(x_grid * y_grid):
    index = np.random.randint(0, n_training)
    axes[i].imshow(X_train[index])
    axes[i].set_title(y_train[index])
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Data preparation

# %% [markdown]
# normalize data

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# reshape target

# %%
y_train = y_train.flatten()
y_test = y_test.flatten()

# %%
n_target = len(set(y_train))

# %% [markdown]
# ## Train model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# %%
i = Input(shape=X_train.shape[1:])
x = Conv2D(64, (3,3), 2, activation='relu')(i)
x = BatchNormalization()(x)
x = Conv2D(64, (3,3), 2, activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D()(x)
x = Dropout(0.25)(x)

x = Conv2D(128, (3,3), 2, activation='relu')(i)
x = BatchNormalization()(x)
x = Conv2D(128, (3,3), 2, activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D()(x)
x = Dropout(0.4)(x)

x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(n_target, activation='softmax')(x)

# %%
model = Model(i, x)

# %%
model.summary()
# Out:
# Model: "functional_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 15, 15, 128)       3584
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 15, 15, 128)       512
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 7, 7, 128)         147584
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 7, 7, 128)         512
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1024)              1180672
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                10250
# =================================================================
# Total params: 2,392,714
# Trainable params: 2,392,202
# Non-trainable params: 512
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Image Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 32
dg = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True, rotation_range=90)
img_dg = dg.flow(X_train, y_train, batch_size)

# %%
r = model.fit(img_dg, steps_per_epoch=n_training//batch_size, epochs=50, shuffle=True)
# Out:
# Epoch 1/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.6469 - accuracy: 0.4083
# Epoch 2/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.5976 - accuracy: 0.4280
# Epoch 3/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.5589 - accuracy: 0.4431
# Epoch 4/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.5328 - accuracy: 0.4518
# Epoch 5/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.5034 - accuracy: 0.4649
# Epoch 6/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.4725 - accuracy: 0.4758
# Epoch 7/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.4438 - accuracy: 0.4869
# Epoch 8/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.4264 - accuracy: 0.4939
# Epoch 9/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.4087 - accuracy: 0.5002
# Epoch 10/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.3949 - accuracy: 0.5051
# Epoch 11/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.3764 - accuracy: 0.5135
# Epoch 12/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.3587 - accuracy: 0.5173
# Epoch 13/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.3420 - accuracy: 0.5225
# Epoch 14/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.3357 - accuracy: 0.5289
# Epoch 15/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.3172 - accuracy: 0.5352
# Epoch 16/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.3056 - accuracy: 0.5382
# Epoch 17/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2963 - accuracy: 0.5416
# Epoch 18/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2901 - accuracy: 0.5475
# Epoch 19/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.2783 - accuracy: 0.5517
# Epoch 20/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2715 - accuracy: 0.5509
# Epoch 21/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2580 - accuracy: 0.5551
# Epoch 22/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.2588 - accuracy: 0.5567
# Epoch 23/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2507 - accuracy: 0.5594
# Epoch 24/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.2421 - accuracy: 0.5613
# Epoch 25/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2349 - accuracy: 0.5620
# Epoch 26/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2392 - accuracy: 0.5647
# Epoch 27/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2312 - accuracy: 0.5652
# Epoch 28/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.2289 - accuracy: 0.5677
# Epoch 29/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.2165 - accuracy: 0.5723
# Epoch 30/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.2198 - accuracy: 0.5731
# Epoch 31/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.2121 - accuracy: 0.5706
# Epoch 32/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.2052 - accuracy: 0.5759
# Epoch 33/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1986 - accuracy: 0.5771
# Epoch 34/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.1980 - accuracy: 0.5783
# Epoch 35/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.1934 - accuracy: 0.5822
# Epoch 36/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.1945 - accuracy: 0.5805
# Epoch 37/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1875 - accuracy: 0.5807
# Epoch 38/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1852 - accuracy: 0.5830
# Epoch 39/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1796 - accuracy: 0.5847
# Epoch 40/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1765 - accuracy: 0.5868
# Epoch 41/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1673 - accuracy: 0.5914
# Epoch 42/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1682 - accuracy: 0.5897
# Epoch 43/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1628 - accuracy: 0.5932
# Epoch 44/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1677 - accuracy: 0.5906
# Epoch 45/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1593 - accuracy: 0.5939
# Epoch 46/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.1539 - accuracy: 0.5931
# Epoch 47/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1513 - accuracy: 0.5967
# Epoch 48/50
# 1562/1562 [==============================] - 37s 24ms/step - loss: 1.1561 - accuracy: 0.5944
# Epoch 49/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.1538 - accuracy: 0.5947
# Epoch 50/50
# 1562/1562 [==============================] - 38s 24ms/step - loss: 1.1441 - accuracy: 0.5974

# %% [markdown]
# ## Evaluate model

# %% [markdown]
# Plot loss and accuracy

# %%
plt.figure(figsize=(16, 8))
plt.plot(r.history['accuracy'], label='Train accuracy')
# plt.plot(r.history['val_accuracy'], label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 8))
plt.plot(r.history['loss'], label='Train loss')
# plt.plot(r.history['val_loss'], label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Make Predictions

# %%
t_loss, t_acc = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {t_acc}')
print(f'Test Loss: {t_loss}')
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9916 - accuracy: 0.6484
# Test Accuracy: 0.6484000086784363
# Test Loss: 0.9916326403617859

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
y_pred = model.predict(X_test).argmax(axis=1)
cf = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(cf, annot=True, fmt='d', linewidths=0.5)
plt.xlabel('Test data')
plt.ylabel('Prediction')
plt.show()
