# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle

# %%
with open('train.p', mode='rb') as training_data:
    train = pickle.load(training_data)

with open('valid.p', mode='rb') as valid_data:
    valid = pickle.load(valid_data)

with open('test.p', mode='rb') as test_data:
    test = pickle.load(test_data)

# %%
X_train, y_train = train['features'], train['labels']
X_val, y_val = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ### Visualize Data

# %%
# random visualization
plt.imshow(X_train[np.random.choice(len(X_train))])
plt.show()

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# Grayscale Image

# %%
X_train = np.sum(X_train/3, axis=3, keepdims=True)
X_val = np.sum(X_val/3, axis=3, keepdims=True)
X_test = np.sum(X_test/3, axis=3, keepdims=True)

# %%
X_train.shape
# Out:
# (34799, 32, 32, 1)

# %% [markdown]
# Normalize Image

# %%
X_train = (X_train - 128) / 128
X_val = (X_val - 128) / 128
X_test = (X_test - 128) / 128

# %%
X_train.shape
# Out:
# (34799, 32, 32, 1)

# %% [markdown]
# ### Model Train

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Input, AveragePooling2D, Conv2D
from tensorflow.keras.optimizers import Adam

# %%
# LeNet Architechture
i = Input(shape=(32, 32, 1))
x = Conv2D(filters=6, kernel_size=(5, 5), activation='relu')(i)
x = AveragePooling2D()(x)
x = Conv2D(filters=16, kernel_size=(5, 5), activation='relu')(x)
x = AveragePooling2D()(x)
x = Flatten()(x)
x = Dense(120, activation='relu')(x)
x = Dense(84, activation='relu')(x)
x = Dense(43, activation='softmax')(x) # 43 classes output

# %%
model = Model(i, x)
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 1)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(lr=0.001), metrics=['accuracy'])

# %%
r = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 272/272 [==============================] - 18s 68ms/step - loss: 1.9656 - accuracy: 0.4583 - val_loss: 1.0497 - val_accuracy: 0.6844
# Epoch 2/50
# 272/272 [==============================] - 18s 67ms/step - loss: 0.6476 - accuracy: 0.8119 - val_loss: 0.7525 - val_accuracy: 0.7955
# Epoch 3/50
# 272/272 [==============================] - 18s 67ms/step - loss: 0.4082 - accuracy: 0.8857 - val_loss: 0.7003 - val_accuracy: 0.8098
# Epoch 4/50
# 272/272 [==============================] - 18s 67ms/step - loss: 0.3025 - accuracy: 0.9175 - val_loss: 0.6960 - val_accuracy: 0.8129
# Epoch 5/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.2408 - accuracy: 0.9347 - val_loss: 0.6426 - val_accuracy: 0.8320
# Epoch 6/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.1992 - accuracy: 0.9461 - val_loss: 0.5942 - val_accuracy: 0.8517
# Epoch 7/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.1635 - accuracy: 0.9561 - val_loss: 0.6233 - val_accuracy: 0.8472
# Epoch 8/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.1389 - accuracy: 0.9624 - val_loss: 0.6148 - val_accuracy: 0.8574
# Epoch 9/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.1179 - accuracy: 0.9678 - val_loss: 0.7098 - val_accuracy: 0.8517
# Epoch 10/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0980 - accuracy: 0.9737 - val_loss: 0.6021 - val_accuracy: 0.8599
# Epoch 11/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0840 - accuracy: 0.9777 - val_loss: 0.6184 - val_accuracy: 0.8669
# Epoch 12/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0798 - accuracy: 0.9784 - val_loss: 0.6493 - val_accuracy: 0.8590
# Epoch 13/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0639 - accuracy: 0.9822 - val_loss: 0.7207 - val_accuracy: 0.8719
# Epoch 14/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0580 - accuracy: 0.9833 - val_loss: 0.7185 - val_accuracy: 0.8540
# Epoch 15/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0501 - accuracy: 0.9857 - val_loss: 0.8204 - val_accuracy: 0.8612
# Epoch 16/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0483 - accuracy: 0.9859 - val_loss: 0.7261 - val_accuracy: 0.8703
# Epoch 17/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0422 - accuracy: 0.9866 - val_loss: 0.7348 - val_accuracy: 0.8805
# Epoch 18/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0321 - accuracy: 0.9906 - val_loss: 0.7551 - val_accuracy: 0.8660
# Epoch 19/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0326 - accuracy: 0.9905 - val_loss: 0.7995 - val_accuracy: 0.8639
# Epoch 20/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0342 - accuracy: 0.9897 - val_loss: 0.6842 - val_accuracy: 0.8805
# Epoch 21/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0330 - accuracy: 0.9899 - val_loss: 0.7546 - val_accuracy: 0.8562
# Epoch 22/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0233 - accuracy: 0.9929 - val_loss: 0.6016 - val_accuracy: 0.8939
# Epoch 23/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0185 - accuracy: 0.9948 - val_loss: 0.7359 - val_accuracy: 0.8753
# Epoch 24/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0270 - accuracy: 0.9918 - val_loss: 0.7634 - val_accuracy: 0.8735
# Epoch 25/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0170 - accuracy: 0.9949 - val_loss: 0.8895 - val_accuracy: 0.8642
# Epoch 26/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.7351 - val_accuracy: 0.9023
# Epoch 47/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.7463 - val_accuracy: 0.9132
# Epoch 48/50
# 272/272 [==============================] - 18s 65ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.8313 - val_accuracy: 0.8932
# Epoch 49/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.8000 - val_accuracy: 0.8862
# Epoch 50/50
# 272/272 [==============================] - 18s 66ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.5829 - val_accuracy: 0.9118

# %% [markdown]
# ### Model Evaluation

# %%
plt.figure(figsize=(16, 8))
plt.plot(r.history['accuracy'], label='Train Accuracy')
plt.plot(r.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 8))
plt.plot(r.history['loss'], label='Train Loss')
plt.plot(r.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Predictions

# %%
model.evaluate(X_test, y_test)
# Out:
# 395/395 [==============================] - 4s 9ms/step - loss: 1.0803 - accuracy: 0.8994
# [1.0803077220916748, 0.8993666172027588]

# %%
y_pred = model.predict(X_test).argmax(axis=1)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
plt.figure(figsize=(24, 15))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, linewidths=0.7)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84        60
#            1       0.86      0.97      0.91       720
#            2       0.91      0.92      0.92       750
#            3       0.87      0.93      0.90       450
#            4       0.96      0.88      0.92       660
#            5       0.93      0.86      0.90       630
#            6       0.99      0.81      0.89       150
#            7       0.96      0.76      0.85       450
#            8       0.76      0.92      0.83       450
#            9       0.94      0.96      0.95       480
#           10       0.97      0.98      0.97       660
#           11       0.95      0.89      0.92       420
#           12       0.97      0.90      0.93       690
#           13       0.99      0.98      0.99       720
#           14       0.96      0.90      0.93       270
#           15       0.97      0.96      0.96       210
#           16       0.94      0.97      0.96       150
#           17       1.00      0.91      0.95       360
#           18       0.93      0.73      0.82       390
#           19       0.68      0.53      0.60        60
#           20       0.62      0.81      0.70        90
#           21       0.74      0.89      0.81        90
#           22       0.98      0.88      0.93       120
#           23       0.85      0.75      0.80       150
#           24       0.88      0.79      0.83        90
#           25       0.79      0.90      0.84       480
#           26       0.74      0.81      0.77       180
#           27       0.57      0.50      0.53        60
#           28       0.87      0.91      0.89       150
#           29       0.88      0.79      0.83        90
#           30       0.56      0.81      0.66       150
#           31       0.96      0.98      0.97       270
#           32       0.60      0.75      0.67        60
#           33       0.88      0.92      0.90       210
#           34       0.93      0.94      0.93       120
#           35       0.97      0.94      0.95       390
#           36       0.93      0.97      0.95       120
#           37       0.70      0.92      0.79        60
#           38       0.94      0.94      0.94       690
#           39       0.84      0.93      0.88        90
#           40       0.69      0.63      0.66        90
#           41       0.83      0.75      0.79        60
#           42       0.96      0.89      0.92        90
#
#     accuracy                           0.90     12630
#    macro avg       0.86      0.86      0.86     12630
# weighted avg       0.91      0.90      0.90     12630
